# %% [markdown]
# # Paper: **COVID-19 Case Prediction in Virginia Based On Demographic Factors**
# ## Authors: Saiteja Bevara, Rithik Yelisetty and William Zhang (Code available at https://github.com/rithik/COVID-19-VA-Predictions)
#
# ### presented by Insightful Interfaces

# %%
#import necessary modules
import os
import heapq
import re
import json
import string
import math
import random
import pandas as pd
import numpy as np
import sklearn

import matplotlib.pyplot as plt

from itertools import chain

# %%
# Import necessary Tensorflow and Keras modules
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K
from sklearn.model_selection import StratifiedKFold

from tensorflow.python.client import device_lib

# Tells us about GPU assigned by Colab
print(device_lib.list_local_devices()) # list of DeviceAttributes

# Set random seed to ensure consistent shuffling
tf.compat.v1.enable_eager_execution()
tf.random.set_seed(
    42
)
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 14203848336818752860
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 3737056540510918664
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 6526326828683273444
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 14640891840
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 1787270325519920127
# physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
# ]

# %%
from google.colab import drive
drive.mount('/content/drive')
path = 'drive/MyDrive/CS4774/covid/dataset.csv'
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1. Why demographic data?
# People have made various claims regarding how different demographics have affected the trends regarding the spread of COVID-19. Prominent predictions that are noted in common media outlets have been based primarily on previous case counts. We want our predictions for the spread of COVID-19 to include demographic data and income in order to better predict the next hotspots in the state of Virginia.
#
# ## 2. What is our dataset comprised of?
# We used three primary datasets in order to train our model. Data regarding COVID-19 cases (per locality) was sourced from https://data.virginia.gov/Government/VDH-COVID-19-PublicUseDataset-Cases/bre9-aqqr/data. Socioeconomic data such as unemployment rate and median household income (per locality) was obtained from https://data.ers.usda.gov/reports.aspx?ID=17828. Demographic data regarding distribution of age and race was collected from https://www.cdc.gov/nchs/nvss/bridged_race.htm#Newest%20Data%20Release. All of this data was combined based on the FIPS code (unique per locality).
#
# ## 3. What is our goal?
# Predict future cases of COVID-19 based on past confirmed case count as well as the population and demographics of the area in Virginia. The factors / model features that will be considered will be case count, along with demographic data such as population density, race distribution, age group distribution, median income and unemployment rate. The output or label assigned will be predicted number of new cases expected for the next day.

# %%
def make_covid_graph(path):
    x = pd.read_csv(path).sort_values(by=['report-date'])
    y = x[['c1']].astype('float32')
    counties = list(set(x['locality']))
    max_case_counts = list()
    for county in counties:
        max_case_counts.append((int(max(y.loc[x['locality'] == county].values)), county))
    counties_to_plot = sorted(max_case_counts, reverse=True)[:15]
    min_x = 1000
    max_x = 0
    max_y = 0
    for max_case, county in counties_to_plot:
        x_sel = x[x['locality'] == county]['num-days'].astype('int')
        temp = min(x_sel)
        if min_x > temp:
            min_x = temp
        temp = max(x_sel)
        if max_x < temp:
            max_x = temp
        y_sel = y.loc[x['locality'] == county].astype('float32')
        temp = float(max(y_sel.values))
        if max_y < temp:
            max_y = temp
        plt.plot(x_sel, y_sel, '-', label=county)
    plt.ylim(0, max_y + 10)
    plt.xlim(min_x, max_x)
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='medium')
    plt.show()

make_covid_graph(path)

# %% [markdown]
# This graph shows the trend of COVID-19 cases for a few sample counties in Virginia. As visible by the data, each county has its own unique trajectory in terms of cases.

# %%
def make_race_graph(path):
    df = pd.read_csv(path).sort_values(by=['report-date'])
    df = df[df['report-date'] == '2020-11-30']

    df = df[df['fips'] <= 51060]
    x = df[['fips', 'white', 'black', 'american-indian', 'asian']].to_numpy().astype('float32')

    labels = df['fips'].to_numpy()

    white = df['white'].to_numpy()
    black = df['black'].to_numpy()
    ai = df['american-indian'].to_numpy()
    asian = df['asian'].to_numpy()

    width = 0.8

    fig, ax = plt.subplots()

    ax.bar(labels, white, width, label='White')
    ax.bar(labels, black, width, bottom=white,
        label='Black')
    ax.bar(labels, ai, width, bottom=white+black,
        label='American Indian')
    ax.bar(labels, asian, width, bottom=white+black+ai,
        label='Asian')

    ax.set_xlabel("FIPS")
    ax.set_ylabel('Percent of Population')
    ax.set_title('Race Breakdown by FIPS district')
    ax.legend()

    plt.show()
make_race_graph(path)

# %% [markdown]
# This graph shows the breakdown of the population for a few sample FIPS districts based on race.  As displayed, there is a considerable amount of variance in the race distributions among the populations of each district.

# %%
def make_age_graph(path):
    df = pd.read_csv(path).sort_values(by=['report-date'])
    df = df[df['report-date'] == '2020-11-30']

    df = df[df['fips'] <= 51060]
    x = df[['fips', 'age0-14', 'age15-24', 'age25-34', 'age35-44', 'age45-54', 'age55-64', 'age65-85']].to_numpy().astype('float32')
    # print(x)
    labels = df['fips'].to_numpy()

    a0 = df['age0-14'].to_numpy()
    a1 = df['age15-24'].to_numpy()
    a2 = df['age25-34'].to_numpy()
    a3 = df['age35-44'].to_numpy()
    a4 = df['age45-54'].to_numpy()
    a5 = df['age55-64'].to_numpy()
    a6 = df['age65-85'].to_numpy()

    width = 0.8      

    fig, ax = plt.subplots()

    ax.bar(labels, a0, width, label='Age 0-14')
    ax.bar(labels, a1, width, bottom=a0,
        label='Age 15-24')
    ax.bar(labels, a2, width, bottom=a0+a1,
        label='Age 25-34')
    ax.bar(labels, a3, width, bottom=a0+a1+a2,
        label='Age 35-44')
    ax.bar(labels, a4, width, bottom=a0+a1+a2+a3,
        label='Age 45-54')
    ax.bar(labels, a5, width, bottom=a0+a1+a2+a3+a4,
        label='Age 55-64')
    ax.bar(labels, a6, width, bottom=a0+a1+a2+a3+a4+a5,
        label='Age 65-85')

    ax.set_xlabel("FIPS")
    ax.set_ylabel('Age Precent')
    ax.set_title('Age Breakdown by FIPS district')
    ax.legend()

    plt.show()
make_age_graph(path)

# %% [markdown]
# This graph shows the breakdown of the population for a few sample FIPS districts based on age.  As displayed, there is again a significant amount of variance in the age distributions among the populations of each district.

# %% [markdown]
# ## Load Data
#
# Once the dataset has been created, we need to import select columns from the entire dataset. Below, we use the pandas library to sort all of the data by the `report date`.
#
# For the y set, we choose the `c1` column.  The `c1` column represents the current day's number of COVID-19 cases.
#
# For the x set, we select the following columns for each datapoint in the x set: `fips`, `unemployment-percent`, `median-household-income`, `num-days`, `age0-14`, `age15-24`, `age25-34`, `age35-44`, `age45-54`, `age55-64`, `age65-85`, `white`, `black`, `american-indian`, `asian`, `total`, `c2`, `c3`,  `c4`, `c5`, `c6`, `c7`, `c8`, `c9` and `c10`, where each age column represents a percent of the population that consists of this age group, each race column represents the percent of the population that falls into a specific race and each `c` column represents the number of COVID-19 cases for days prior to `c1`, with a higher number representing older days.
#
# The data is then shuffled and split into train and test datasets, where 90% of the data is used for training and 10% is used for testing.

# %%
def load_data(path):
    df = pd.read_csv(path).sort_values(by=['report-date'])
    x = df[['fips', 'unemployment-percent', 'median-household-income', 'num-days', 
            'age0-14', 'age15-24', 'age25-34', 'age35-44', 'age45-54', 'age55-64', 'age65-85', 'white', 'black',
            'american-indian', 'asian', 'total', 'c2', 'c3',  'c4', 'c5', 'c6', 'c7', 'c8', 'c9', 'c10']].to_numpy().astype('float32')
    y = df[['c1']].to_numpy().astype('float32')
    
    x, y = sklearn.utils.shuffle(x, y)
    train_test_split = int(x.shape[0] * 0.9)
    x_train = x[:train_test_split]
    y_train = y[:train_test_split]
    x_test = x[train_test_split:]
    y_test = y[train_test_split:]
    return x_train, x_test, y_train, y_test

# %% [markdown]
# ## Model Creation
#
# ### Soft Accuracy
# The `soft_acc` function represents our model's accuracy metric. A traditional accuracy metric would compare the predicted case count strictly to the true case count to see if they are explicitly equal. However, we wanted to provide leniancy to our model and therefore decided to use this function to classify an accurate prediction as one that falls within a certain threshold of cases. In this scenario, our threshold was 2.5 cases.
#
# The `soft_acc` function subtracts the true case count from the predicted case count and checks if the absolute value of the difference is less than the threshold (2.5). If it is, it marks the prediction as accurate. Otherwise, the prediction is marked as inaccurate.

# %%
def soft_acc(y_true, y_pred):
    difference = tf.math.subtract(y_true, y_pred)
    def equaler(t): return 1.0 if abs(t) < 2.5 else 0.0
    bools = K.map_fn(equaler, difference)
    val = K.mean(bools)
    return val

# %% [markdown]
# ### MLP Model
#
# In order to solve this problem, the team decided to use an MLP model. We used a sequential model to run data through each of the layers. The first layer, as well as subsequent hidden layers, use the `relu` activation function and have units of size `hidden_dim`. There is an additional dropout layer after all of the hidden layers to remove all of the extraneous points to improve model generalization. The last layer uses a `linear` activation function and has only 1 unit because we only predict one value: case count. We used a `linear` activation function since our problem is primarily a regression-based problem with numerical output. The optimizer was specified by `args['opt']` and was selected with hyperparameter tuning. The loss function selected was Mean Squared Logarithmic Error.

# %%
def create_mlp(args=None):
    model = Sequential()
    # Define model architecture
    model.add(Dense(units=args['hidden_dim'],
                    activation='relu', input_dim=args['x_train_shape'][1]))  # 42
    for k in range(args['hidden_layer']):
        model.add(Dense(units=args['hidden_dim'], activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(units=1, activation='linear'))
    # Optimizer
    optimizer = keras.optimizers.SGD(lr=args['learning_rate']) if args['opt'] == 'sgd' else keras.optimizers.Adam(lr=args['learning_rate'])
    # Compile
    model.compile(loss=keras.losses.MeanSquaredLogarithmicError(), optimizer=optimizer, metrics=[soft_acc])

    return model

# %% [markdown]
# ## Model Training and Selection
#
# ### Training the Model
#
# The model was created using the args specified and subsequently fit on the `x_train` and `y_train` data. Shuffling was ensured by using the `shuffle=True` parameter to the `model.fit` method and a `validation_split` of 0.1 was used to specify the portion of the data to be used as a validation set.

# %%
def train_model(x_train, y_train, x_val, y_val, args):
    model = create_mlp(args)
    if len(x_val) > 0 and len(y_val) > 0:
        history = model.fit(x_train, y_train, batch_size=args['batch_size'], epochs=args['epoch'], validation_data=(x_val, y_val), shuffle=True)
    else:
        history = model.fit(x_train, y_train, batch_size=args['batch_size'], epochs=args['epoch'], validation_split=0.1, shuffle=True)
    return model, history

# %% [markdown]
# ### Model Selection
#
# The following parameters were tested for each argument:
#
# `learning_rate`: 0.0000005, 0.0000003, 0.000001, 0.00005, 0.0001
#
# `opt`: 'adam', 'sgd'
#
# `epoch`: 5, 10, 20
#
# `hidden_dim`: 10, 20, 50, 100, 200, 400
#
# `hidden_layer`: 1, 2, 3, 5, 10, 15, 20, 30
#
# For each set of parameters, the model was trained and fit to find the accuracy. The model with the highest resulting validation accuracy was chosen as the optimal model.
#
# The best model consisted of the following parameters:
# ```
# args = {
#         'batch_size': 8,
#         'epoch': 10,
#         'learning_rate': 0.000001,
#         'hidden_dim': 200,
#         'hidden_layer': 20,
#         'opt': 'adam',
#         'x_train_shape': x_train.shape
# }
# ```

# %%
def train_and_select_model(x_train, y_train):
    params = [{
        'batch_size': 8,
        'epoch': 10,
        'learning_rate': 0.000001,
        'hidden_dim': 200,
        'hidden_layer': 20,
        'opt': 'adam',
        'x_train_shape': x_train.shape
    }]
    best_acc = 0
    best_model = None
    best_history = None
    best_params = params[0]
    for args in params:
        skf = StratifiedKFold(n_splits=10)
        accuracies = []
        for train_index, test_index in skf.split(x_train, y_train):
            x_train_new, x_val = x_train[train_index], x_train[test_index]
            y_train_new, y_val = y_train[train_index], y_train[test_index]
            model, history = train_model(x_train_new, y_train_new, x_val, y_val, args=args)
            accuracies.append(history.history['val_soft_acc'][-1])
        average_accuracy = sum(accuracies) / len(accuracies)
        if average_accuracy > best_acc:
            best_params = args
            best_acc = average_accuracy
    best_model, best_history = train_model(x_train, y_train, x_val=[], y_val=[], args=best_params)
            
    return best_model, best_history

# %% [markdown]
# ## Plot History
#
# This method helps us understand whether the model is overfitting or underfitting the data.

# %%
def plot_history(history, plot_title=''):
    train_loss_history = history.history['loss']
    val_loss_history = history.history['val_loss']

    train_acc_history = history.history['soft_acc']
    val_acc_history = history.history['val_soft_acc']
    plt.plot(range(len(train_loss_history)), train_loss_history, label='training_loss')
    plt.plot(range(len(val_loss_history)), val_loss_history, label='validation_loss')
    plt.legend(loc='best')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training vs Validation Losses')
    plt.show()

    plt.plot(range(len(train_acc_history)), train_acc_history, label='training_accuracy')
    plt.plot(range(len(val_acc_history)), val_acc_history, label='validation_accuracy')
    plt.legend(loc='best')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Training vs Validation Accuracy')
    plt.show()

# %%
x_train, x_test, y_train, y_test = load_data(path)
model, history = train_and_select_model(x_train, y_train)
plot_history(history)

loss_test, acc_test = model.evaluate(x_test, y_test)
print("Loss: {}, Accuracy: {}".format(loss_test, acc_test))

print(model.summary())
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   % (min_groups, self.n_splits)), UserWarning)
# Epoch 1/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 1.4341 - soft_acc: 0.2519 - val_loss: 0.9649 - val_soft_acc: 0.3527
# Epoch 2/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.9890 - soft_acc: 0.4486 - val_loss: 0.7909 - val_soft_acc: 0.5791
# Epoch 3/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.8447 - soft_acc: 0.5844 - val_loss: 0.7437 - val_soft_acc: 0.6287
# Epoch 4/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7853 - soft_acc: 0.6193 - val_loss: 0.7314 - val_soft_acc: 0.6294
# Epoch 5/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.7576 - soft_acc: 0.6326 - val_loss: 0.7300 - val_soft_acc: 0.6355
# Epoch 6/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.7396 - soft_acc: 0.6378 - val_loss: 0.7246 - val_soft_acc: 0.6463
# Epoch 7/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7314 - soft_acc: 0.6428 - val_loss: 0.7193 - val_soft_acc: 0.6439
# Epoch 8/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.7271 - soft_acc: 0.6439 - val_loss: 0.7211 - val_soft_acc: 0.6449
# Epoch 9/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7192 - soft_acc: 0.6452 - val_loss: 0.7140 - val_soft_acc: 0.6456
# Epoch 10/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7150 - soft_acc: 0.6483 - val_loss: 0.7158 - val_soft_acc: 0.6497
# Epoch 1/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 1.4222 - soft_acc: 0.3746 - val_loss: 0.8576 - val_soft_acc: 0.5679
# Epoch 2/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.9322 - soft_acc: 0.5450 - val_loss: 0.7773 - val_soft_acc: 0.6098
# Epoch 3/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.8169 - soft_acc: 0.6041 - val_loss: 0.7460 - val_soft_acc: 0.6240
# Epoch 4/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.7716 - soft_acc: 0.6290 - val_loss: 0.7218 - val_soft_acc: 0.6382
# Epoch 5/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.7496 - soft_acc: 0.6336 - val_loss: 0.7240 - val_soft_acc: 0.6338
# Epoch 6/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.7353 - soft_acc: 0.6380 - val_loss: 0.7178 - val_soft_acc: 0.6321
# Epoch 7/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.7324 - soft_acc: 0.6418 - val_loss: 0.7126 - val_soft_acc: 0.6443
# Epoch 8/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.7231 - soft_acc: 0.6442 - val_loss: 0.7133 - val_soft_acc: 0.6399
# Epoch 9/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.7184 - soft_acc: 0.6437 - val_loss: 0.7218 - val_soft_acc: 0.6230
# Epoch 10/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.7146 - soft_acc: 0.6452 - val_loss: 0.7080 - val_soft_acc: 0.6389
# Epoch 1/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 2.0203 - soft_acc: 0.1558 - val_loss: 1.1126 - val_soft_acc: 0.1998
# Epoch 2/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 1.3204 - soft_acc: 0.2611 - val_loss: 0.9380 - val_soft_acc: 0.3613
# Epoch 3/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.9945 - soft_acc: 0.4621 - val_loss: 0.7845 - val_soft_acc: 0.5794
# Epoch 4/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.8412 - soft_acc: 0.5815 - val_loss: 0.7331 - val_soft_acc: 0.6280
# Epoch 5/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.7764 - soft_acc: 0.6174 - val_loss: 0.7143 - val_soft_acc: 0.6301
# Epoch 6/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.7454 - soft_acc: 0.6306 - val_loss: 0.7145 - val_soft_acc: 0.6315
# Epoch 7/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.7310 - soft_acc: 0.6380 - val_loss: 0.7072 - val_soft_acc: 0.6407
# Epoch 8/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.7246 - soft_acc: 0.6400 - val_loss: 0.7013 - val_soft_acc: 0.6463
# Epoch 9/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.7223 - soft_acc: 0.6414 - val_loss: 0.6948 - val_soft_acc: 0.6405
# Epoch 10/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.7178 - soft_acc: 0.6448 - val_loss: 0.6981 - val_soft_acc: 0.6497
# Epoch 1/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 1.4606 - soft_acc: 0.3490 - val_loss: 0.8227 - val_soft_acc: 0.5821
# Epoch 2/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.9873 - soft_acc: 0.5177 - val_loss: 0.7345 - val_soft_acc: 0.6264
# Epoch 3/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.8380 - soft_acc: 0.6027 - val_loss: 0.7108 - val_soft_acc: 0.6419
# Epoch 4/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7781 - soft_acc: 0.6266 - val_loss: 0.6989 - val_soft_acc: 0.6490
# Epoch 5/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7576 - soft_acc: 0.6379 - val_loss: 0.6911 - val_soft_acc: 0.6486
# Epoch 6/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7382 - soft_acc: 0.6416 - val_loss: 0.6873 - val_soft_acc: 0.6520
# Epoch 7/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7299 - soft_acc: 0.6450 - val_loss: 0.6864 - val_soft_acc: 0.6574
# Epoch 8/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7257 - soft_acc: 0.6445 - val_loss: 0.6822 - val_soft_acc: 0.6571
# Epoch 9/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7196 - soft_acc: 0.6482 - val_loss: 0.6813 - val_soft_acc: 0.6659
# Epoch 10/10
# 3328/3328 [==============================] - 22s 6ms/step - loss: 0.7178 - soft_acc: 0.6491 - val_loss: 0.6812 - val_soft_acc: 0.6608
# Epoch 1/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 1.9995 - soft_acc: 0.1498 - val_loss: 0.9991 - val_soft_acc: 0.2315
# Epoch 2/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 1.2068 - soft_acc: 0.2973 - val_loss: 0.8558 - val_soft_acc: 0.5000
# Epoch 3/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.9325 - soft_acc: 0.5109 - val_loss: 0.7499 - val_soft_acc: 0.6294
# Epoch 4/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.8237 - soft_acc: 0.6042 - val_loss: 0.7280 - val_soft_acc: 0.6407
# Epoch 5/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7729 - soft_acc: 0.6269 - val_loss: 0.7233 - val_soft_acc: 0.6505
# Epoch 6/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7531 - soft_acc: 0.6370 - val_loss: 0.7243 - val_soft_acc: 0.6525
# Epoch 7/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.7417 - soft_acc: 0.6380 - val_loss: 0.7155 - val_soft_acc: 0.6470
# Epoch 8/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7333 - soft_acc: 0.6424 - val_loss: 0.7152 - val_soft_acc: 0.6477
# Epoch 9/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7308 - soft_acc: 0.6421 - val_loss: 0.7174 - val_soft_acc: 0.6578
# Epoch 10/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7221 - soft_acc: 0.6452 - val_loss: 0.7127 - val_soft_acc: 0.6649
# Epoch 1/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 2.1253 - soft_acc: 0.1685 - val_loss: 0.9864 - val_soft_acc: 0.3101
# Epoch 2/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 1.0943 - soft_acc: 0.4322 - val_loss: 0.7726 - val_soft_acc: 0.6176
# Epoch 3/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.8665 - soft_acc: 0.5874 - val_loss: 0.7223 - val_soft_acc: 0.6399
# Epoch 4/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7869 - soft_acc: 0.6250 - val_loss: 0.7048 - val_soft_acc: 0.6511
# Epoch 5/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7555 - soft_acc: 0.6363 - val_loss: 0.6997 - val_soft_acc: 0.6626
# Epoch 6/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7404 - soft_acc: 0.6396 - val_loss: 0.6999 - val_soft_acc: 0.6592
# Epoch 7/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7305 - soft_acc: 0.6448 - val_loss: 0.6964 - val_soft_acc: 0.6670
# Epoch 8/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7227 - soft_acc: 0.6460 - val_loss: 0.6965 - val_soft_acc: 0.6655
# Epoch 9/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7204 - soft_acc: 0.6475 - val_loss: 0.6936 - val_soft_acc: 0.6672
# Epoch 10/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7182 - soft_acc: 0.6482 - val_loss: 0.6931 - val_soft_acc: 0.6645
# Epoch 1/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 1.7915 - soft_acc: 0.1575 - val_loss: 1.0598 - val_soft_acc: 0.1699
# Epoch 2/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 1.1906 - soft_acc: 0.3280 - val_loss: 0.8124 - val_soft_acc: 0.5095
# Epoch 3/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.9164 - soft_acc: 0.5200 - val_loss: 0.7150 - val_soft_acc: 0.6294
# Epoch 4/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.8098 - soft_acc: 0.6058 - val_loss: 0.6953 - val_soft_acc: 0.6483
# Epoch 5/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7696 - soft_acc: 0.6280 - val_loss: 0.6895 - val_soft_acc: 0.6436
# Epoch 6/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7526 - soft_acc: 0.6321 - val_loss: 0.6870 - val_soft_acc: 0.6524
# Epoch 7/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7405 - soft_acc: 0.6420 - val_loss: 0.6838 - val_soft_acc: 0.6591
# Epoch 8/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7318 - soft_acc: 0.6420 - val_loss: 0.6831 - val_soft_acc: 0.6595
# Epoch 9/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.7284 - soft_acc: 0.6435 - val_loss: 0.6787 - val_soft_acc: 0.6554
# Epoch 10/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7255 - soft_acc: 0.6456 - val_loss: 0.6792 - val_soft_acc: 0.6605
# Epoch 1/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 1.4055 - soft_acc: 0.3902 - val_loss: 0.8255 - val_soft_acc: 0.5801
# Epoch 2/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.9396 - soft_acc: 0.5508 - val_loss: 0.7068 - val_soft_acc: 0.6226
# Epoch 3/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.8176 - soft_acc: 0.6143 - val_loss: 0.6911 - val_soft_acc: 0.6412
# Epoch 4/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7682 - soft_acc: 0.6346 - val_loss: 0.6839 - val_soft_acc: 0.6439
# Epoch 5/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.7492 - soft_acc: 0.6372 - val_loss: 0.6795 - val_soft_acc: 0.6449
# Epoch 6/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7397 - soft_acc: 0.6425 - val_loss: 0.6775 - val_soft_acc: 0.6443
# Epoch 7/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.7323 - soft_acc: 0.6456 - val_loss: 0.6760 - val_soft_acc: 0.6490
# Epoch 8/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.7267 - soft_acc: 0.6448 - val_loss: 0.6715 - val_soft_acc: 0.6486
# Epoch 9/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.7228 - soft_acc: 0.6463 - val_loss: 0.6699 - val_soft_acc: 0.6500
# Epoch 10/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7187 - soft_acc: 0.6474 - val_loss: 0.6743 - val_soft_acc: 0.6459
# Epoch 1/10
# 3328/3328 [==============================] - 24s 7ms/step - loss: 1.8383 - soft_acc: 0.1563 - val_loss: 1.0931 - val_soft_acc: 0.1436
# Epoch 2/10
# 3328/3328 [==============================] - 24s 7ms/step - loss: 1.2090 - soft_acc: 0.2682 - val_loss: 0.8671 - val_soft_acc: 0.3720
# Epoch 3/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.9730 - soft_acc: 0.4650 - val_loss: 0.7837 - val_soft_acc: 0.5696
# Epoch 4/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.8513 - soft_acc: 0.5707 - val_loss: 0.7399 - val_soft_acc: 0.6166
# Epoch 5/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.7949 - soft_acc: 0.6081 - val_loss: 0.7214 - val_soft_acc: 0.6294
# Epoch 6/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.7690 - soft_acc: 0.6245 - val_loss: 0.7215 - val_soft_acc: 0.6392
# Epoch 7/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.7507 - soft_acc: 0.6307 - val_loss: 0.7165 - val_soft_acc: 0.6436
# Epoch 8/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.7417 - soft_acc: 0.6379 - val_loss: 0.7073 - val_soft_acc: 0.6605
# Epoch 9/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.7342 - soft_acc: 0.6398 - val_loss: 0.7215 - val_soft_acc: 0.6389
# Epoch 10/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.7336 - soft_acc: 0.6408 - val_loss: 0.7037 - val_soft_acc: 0.6686
# Epoch 1/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 2.0395 - soft_acc: 0.1771 - val_loss: 0.9466 - val_soft_acc: 0.2689
# Epoch 2/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 1.2549 - soft_acc: 0.3410 - val_loss: 0.8428 - val_soft_acc: 0.5158
# Epoch 3/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.9776 - soft_acc: 0.4931 - val_loss: 0.7611 - val_soft_acc: 0.6172
# Epoch 4/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.8638 - soft_acc: 0.5837 - val_loss: 0.7319 - val_soft_acc: 0.6338
# Epoch 5/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7975 - soft_acc: 0.6186 - val_loss: 0.7206 - val_soft_acc: 0.6436
# Epoch 6/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7680 - soft_acc: 0.6287 - val_loss: 0.7184 - val_soft_acc: 0.6517
# Epoch 7/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7551 - soft_acc: 0.6365 - val_loss: 0.7124 - val_soft_acc: 0.6466
# Epoch 8/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7405 - soft_acc: 0.6399 - val_loss: 0.7072 - val_soft_acc: 0.6510
# Epoch 9/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7367 - soft_acc: 0.6409 - val_loss: 0.7081 - val_soft_acc: 0.6426
# Epoch 10/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7289 - soft_acc: 0.6451 - val_loss: 0.7031 - val_soft_acc: 0.6466
# Epoch 1/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 1.3949 - soft_acc: 0.3270 - val_loss: 0.8829 - val_soft_acc: 0.5087
# Epoch 2/10
# 3328/3328 [==============================] - 23s 7ms/step - loss: 0.9891 - soft_acc: 0.4684 - val_loss: 0.7943 - val_soft_acc: 0.6037
# Epoch 3/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.8600 - soft_acc: 0.5734 - val_loss: 0.7431 - val_soft_acc: 0.6331
# Epoch 4/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7971 - soft_acc: 0.6158 - val_loss: 0.7347 - val_soft_acc: 0.6469
# Epoch 5/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7587 - soft_acc: 0.6350 - val_loss: 0.7229 - val_soft_acc: 0.6442
# Epoch 6/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7438 - soft_acc: 0.6387 - val_loss: 0.7168 - val_soft_acc: 0.6432
# Epoch 7/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7303 - soft_acc: 0.6442 - val_loss: 0.7102 - val_soft_acc: 0.6442
# Epoch 8/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7252 - soft_acc: 0.6442 - val_loss: 0.7166 - val_soft_acc: 0.6527
# Epoch 9/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7209 - soft_acc: 0.6466 - val_loss: 0.7094 - val_soft_acc: 0.6540
# Epoch 10/10
# 3328/3328 [==============================] - 22s 7ms/step - loss: 0.7213 - soft_acc: 0.6468 - val_loss: 0.7085 - val_soft_acc: 0.6506
# 103/103 [==============================] - 1s 10ms/step - loss: 0.7065 - soft_acc: 0.6369
# Loss: 0.7065104842185974, Accuracy: 0.6369116902351379
# Model: "sequential_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_484 (Dense)            (None, 200)               5200
# _________________________________________________________________
# dense_485 (Dense)            (None, 200)               40200
# _________________________________________________________________
# dense_486 (Dense)            (None, 200)               40200
# _________________________________________________________________
# dense_487 (Dense)            (None, 200)               40200
# _________________________________________________________________
# dense_488 (Dense)            (None, 200)               40200
# _________________________________________________________________
# dense_489 (Dense)            (None, 200)               40200
# _________________________________________________________________
# dense_490 (Dense)            (None, 200)               40200
# _________________________________________________________________
# dense_491 (Dense)            (None, 200)               40200
# _________________________________________________________________
# dense_492 (Dense)            (None, 200)               40200
# _________________________________________________________________
# dense_493 (Dense)            (None, 200)               40200
# _________________________________________________________________
# dense_494 (Dense)            (None, 200)               40200
# _________________________________________________________________
# dense_495 (Dense)            (None, 200)               40200
# _________________________________________________________________
# dense_496 (Dense)            (None, 200)               40200
# _________________________________________________________________
# dense_497 (Dense)            (None, 200)               40200
# _________________________________________________________________
# dense_498 (Dense)            (None, 200)               40200
# _________________________________________________________________
# dense_499 (Dense)            (None, 200)               40200
# _________________________________________________________________
# dense_500 (Dense)            (None, 200)               40200
# _________________________________________________________________
# dense_501 (Dense)            (None, 200)               40200
# _________________________________________________________________
# dense_502 (Dense)            (None, 200)               40200
# _________________________________________________________________
# dense_503 (Dense)            (None, 200)               40200
# _________________________________________________________________
# dense_504 (Dense)            (None, 200)               40200
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 200)               0
# _________________________________________________________________
# dense_505 (Dense)            (None, 1)                 201
# =================================================================
# Total params: 809,401
# Trainable params: 809,401
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Discussion of results
#
# We found that the best performing MLP Model had the following parameters: Batch_size: 8, epoch: 10, learning_rate: 0.000001, hidden_dim: 200, hidden_layer: 20, optimizer: adam. The validation accuracy was about 65% and the test accuracy was about 65%. The training and validation losses are decreasing and converging showing that our model is not overfit. The training and validation accuracies are increasing showing that our model is improving over time.
#
# The baseline accuracy for this project, assuming random guessing, is less than ~0.2% (random guessing). In comparison, our model's accuracy of 65% is relatively high. The largest range of daily new COVID-19 case counts were in Fairfax County and case predictions, in general, ranged from 0 to about 500 cases. The accuracy of the baseline linear model without demographic data was about 30.45\%.
#
# Further work could consider a larger number of demographic factors and take more factors into account (i.e. smoking, population density). Increasing the amount of data for each county or other demographic factors could increase accuracy. Certain input features were more indicative of a higher number of predicted cases.
